# %% [markdown]
# # PCA of Churn Data Using Erdogant-PCA-Library
#
# To:&nbsp;&nbsp;&nbsp;&nbsp; [Magnimind](https://magnimindacademy.com/)
#
# From: Matt Curcio, matt.curcio.ri@gmail.com
#
# Date: 2022-12-27
#
# Re:&nbsp;&nbsp;&nbsp; Churn Analysis from 10/5/2022 to 11/5/2022
#
# - For more information see: [Erdogant_PCA_Library](https://erdogant.github.io/pca/pages/html/index.html)
#
# ## Executive Summary
#
# The normalization step is also incorporated in pca that can be set by the parameter normalize=True.

# %%
import pandas as pd
import numpy as np

import pca
print('PCA version:',pca.__version__)

from pca import pca # See:https://erdogant.github.io/pca/pages/html/index.html
# Out:
# PCA version: 1.9.0

# %%
path = '../data/processed/'
fileName = "mcc_clean_churn.csv"

df = pd.read_csv(path+fileName)

# %%
# Fit transform and include the column labels and row labels
results = model.fit_transform(df)

# Scatter plot with loadings
model.biplot()

#print(model.results['topfeat'])
# Out:
# [pca] >Cleaning previous fitted model results..
# [pca] >Processing dataframe..
# [pca] >Normalizing input data per feature (zero mean and unit variance)..
# [pca] >The PCA reduction is performed on the [18] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[12]
# [pca] >Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [pca] >Outlier detection using SPE/DmodX with n_std=[2]
# [pca] >Plot PC1 vs PC2 with loadings.
# [colourmap]> Warning: Colormap [Set1] can not create [5000] unique colors! Available unique colors: [9].
# [colourmap]> Warning: Colormap [Set1] can not create [5000] unique colors! Available unique colors: [9].
# [pca] >Set parameter "label=None" to ignore the labels and significanly speed up the scatter plot.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 5
#       2 results = model.fit_transform(df)
#       4 # Scatter plot with loadings
# ----> 5 model.biplot()
#       7 print(model.results['topfeat'])
#
# File ~/anaconda3/lib/python3.9/site-packages/pca/pca.py:949, in pca.biplot(self, y, c, s, jitter, n_feat, d3, label, PC, SPE, hotellingt2, alpha_transparency, gradient, color_arrow, fontdict, cmap, title, legend, figsize, visible, fig, verbose)
#     946         texts.append(ax.text(xarrow, yarrow, label, color=txtcolor, fontdict=fontdict))
#     948 # Plot the adjusted text labels to prevent overlap
# --> 949 if len(texts)>0: adjust_text(texts)
#     950 # if visible: plt.show()
#     951 return (fig, ax)
#
# File ~/anaconda3/lib/python3.9/site-packages/adjustText/__init__.py:422, in adjust_text(texts, x, y, add_objects, ax, expand_text, expand_points, expand_objects, expand_align, autoalign, va, ha, force_text, force_points, force_objects, lim, precision, only_move, text_from_text, text_from_points, save_steps, save_prefix, save_format, add_step_numbers, on_basemap, *args, **kwargs)
#     335 def adjust_text(texts, x=None, y=None, add_objects=None, ax=None,
#     336                 expand_text=(1.05, 1.2), expand_points=(1.05, 1.2),
#     337                 expand_objects=(1.05, 1.2), expand_align=(1.05, 1.2),
#    (...)
#     345                 add_step_numbers=True, on_basemap=False,
#     346                 *args, **kwargs):
#     347     """Iteratively adjusts the locations of texts.
#     348
#     349     Call adjust_text the very last, after all plotting (especially
#    (...)
#     420             if required
#     421     """
# --> 422     plt.draw()
#     423     if ax is None:
#     424         ax = plt.gca()
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:948, in draw()
#     936 def draw():
#     937     """
#     938     Redraw the current figure.
#     939
#    (...)
#     946     the current figure.
#     947     """
# --> 948     gcf().canvas.draw_idle()
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py:2054, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2052 if not self._is_idle_drawing:
#    2053     with self._idle_draw_cntx():
# -> 2054         self.draw(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:405, in FigureCanvasAgg.draw(self)
#     401 # Acquire a lock on the shared font cache.
#     402 with RendererAgg.lock, \
#     403      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     404       else nullcontext()):
# --> 405     self.figure.draw(self.renderer)
#     406     # A GUI class may be need to update a window using this draw, so
#     407     # don't forget to call the superclass.
#     408     super().draw()
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py:3071, in Figure.draw(self, renderer)
#    3068         # ValueError can occur when resizing a window.
#    3070 self.patch.draw(renderer)
# -> 3071 mimage._draw_list_compositing_images(
#    3072     renderer, self, artists, self.suppressComposite)
#    3074 for sfig in self.subfigs:
#    3075     sfig.draw(renderer)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:3107, in _AxesBase.draw(self, renderer)
#    3104         a.draw(renderer)
#    3105     renderer.stop_rasterizing()
# -> 3107 mimage._draw_list_compositing_images(
#    3108     renderer, self, artists, self.figure.suppressComposite)
#    3110 renderer.close_group('axes')
#    3111 self.stale = False
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/collections.py:975, in _CollectionWithSizes.draw(self, renderer)
#     973 @artist.allow_rasterization
#     974 def draw(self, renderer):
# --> 975     self.set_sizes(self._sizes, self.figure.dpi)
#     976     super().draw(renderer)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/collections.py:968, in _CollectionWithSizes.set_sizes(self, sizes, dpi)
#     966 self._transforms = np.zeros((len(self._sizes), 3, 3))
#     967 scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# --> 968 self._transforms[:, 0, 0] = scale
#     969 self._transforms[:, 1, 1] = scale
#     970 self._transforms[:, 2, 2] = 1.0
#
# KeyboardInterrupt:

# %%
#col_labels = ['Act_Len', 'Int_Plan', 'VM_Plan', 'Num_VM', 
#              'T_D_Min', 'T_D_Calls', 'T_D_Cost', 
#              'T_E_Min', 'T_E_Calls', 'T_E_Cost', 
#              'T_Nt_Min', 'T_Nt_Calls', 'T_Nt_Cost', 
#              'T_Int_Min', 'T_Int_Calls', 'T_Int_Cost',
#              'Num_Srv_Calls']

model = pca(normalize=True)

# Fit transform & include the column labels
results = model.fit_transform(df)# col_labels=col_labels)

# Set plot parameters: 
# cmap to None and label and legend to False, only Vectors will be plotted.
model.biplot(cmap=None, label=None, legend=False)
# Out:
# [pca] >Processing dataframe..
# [pca] >Normalizing input data per feature (zero mean and unit variance)..
# [pca] >The PCA reduction is performed to capture [95.0%] explained variance using the [18] columns of the input data.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Number of components is [12] that covers the [95.00%] explained variance.
# [pca] >The PCA reduction is performed on the [18] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[12]
# [pca] >Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [pca] >Outlier detection using SPE/DmodX with n_std=[2]
# [pca] >Plot PC1 vs PC2 with loadings.
# (<Figure size 1500x1000 with 1 Axes>,
#  <AxesSubplot: title={'center': '12 Principal Components explain [99.74%] of the variance'}, xlabel='PC1 (11.7% expl.var)', ylabel='PC2 (11.3% expl.var)'>)

# %% [markdown]
# **NOTE 6:** It is interesting to note that the cost and min for the 4 time slots are parallel, indicating that they are collinear and one can be removed.

# %% [markdown]
# ## Scree Plot

# %%
model.plot()
# Out:
# (<Figure size 1500x1000 with 1 Axes>,
#  <AxesSubplot: title={'center': 'Cumulative explained variance\n 12 Principal Components explain [99.74%] of the variance.'}, xlabel='Principle Component', ylabel='Percentage explained variance'>)
